# %%
import os
import datetime

import torch
import torch.utils.data
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from torch import nn, optim
from torch.nn import functional as F
from torchvision.utils import save_image
import numpy as np

# %%
RESULTS_PATH = "./results"
DISENTANGLEMENT_RANGE = [-2, 2]
DISENTANGLEMENT_STEPS = 8

hyperparameters = {
    "lr": 1e-3,
    "batch_size": 64,
    "num_epochs": 1000,
    "log_interval": 100,
    "latent_dim": 2,
    "early_stopping_rounds": 5,
    "early_stopping_min_delta": 1e-2,
    "beta": 5,
    "device": 'cuda' if torch.cuda.is_available() else 'cpu'
}

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True, transform=transforms.ToTensor()),
    batch_size=hyperparameters['batch_size'], shuffle=True)
val_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=hyperparameters['batch_size'], shuffle=False)

# %% [markdown]
# # Data Exploration

# %%
# Get a batch of images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Create a 5x5 grid
fig, axes = plt.subplots(5, 5, figsize=(10, 10))
axes = axes.ravel()

# Plot 25 images
for idx in range(25):
    axes[idx].imshow(images[idx].squeeze(), cmap='gray')
    axes[idx].set_title(f'Label: {labels[idx]}')
    axes[idx].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(784, 400)
        self.fc21 = nn.Linear(400, hyperparameters['latent_dim'])
        self.fc22 = nn.Linear(400, hyperparameters['latent_dim'])
        self.fc3 = nn.Linear(hyperparameters['latent_dim'], 400)
        self.fc4 = nn.Linear(400, 784)

    def encode(self, x):
        h1 = F.relu(self.fc1(x.view(-1, 784)))
        return self.fc21(h1), self.fc22(h1) # return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x) # shape: [batch_size, 784]
        z = self.reparameterize(mu, logvar) # shape: [batch_size, hyperparameters['latent_dim']]
        return self.decode(z), mu, logvar

# %%
model = VAE().to(hyperparameters['device'])
optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'])

# %% [markdown]
# # Training functions

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) # -0.5 since we use logvar instead of sigma^2

    return BCE + hyperparameters['beta'] * KLD, BCE, KLD

def train(epoch):
    model.train()
    train_loss_total= train_bce_loss_total = train_kld_loss_total = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(hyperparameters['device'])
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss, bce_loss, kld_loss = loss_function(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss_total += loss.item()
        train_bce_loss_total += bce_loss.item()
        train_kld_loss_total += kld_loss.item()
        optimizer.step()
        
        # Optional logging after certain log_interval
        # if batch_idx % hyperparameters['log_interval'] == 0:
        #     print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        #         epoch, batch_idx * len(data), len(train_loader.dataset),
        #         100. * batch_idx / len(train_loader),
        #         loss.item() / len(data)))


    print('====> Epoch: {} Average train loss: {:.4f}'.format(
          epoch, train_loss_total / len(train_loader.dataset)))
    
    return train_bce_loss_total / len(train_loader.dataset), train_kld_loss_total / len(train_loader.dataset)


def validate(epoch, result_save_path):
    model.eval()
    val_loss_total = val_bce_loss_total = val_kld_loss_total = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(val_loader):
            data = data.to(hyperparameters['device'])
            recon_batch, mu, logvar = model(data)
            loss, bce_loss, kld_loss = loss_function(recon_batch, data, mu, logvar)
            val_loss_total += loss.item()
            val_bce_loss_total += bce_loss.item()
            val_kld_loss_total += kld_loss.item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n], recon_batch.view(hyperparameters['batch_size'], 1, 28, 28)[:n]])
                save_image(comparison.cpu(), os.path.join(result_save_path, f"reconstruction_{str(epoch)}.png"), nrow=n)

    val_loss_total /= len(val_loader.dataset)
    print('====> Epoch: {} Average validation loss: {:.4f}'.format(epoch, val_loss_total))

    return val_bce_loss_total / len(val_loader.dataset), val_kld_loss_total / len(val_loader.dataset)

# %% [markdown]
# # Training

# %%
result_save_path = os.path.join(RESULTS_PATH, str(datetime.datetime.now()))
if not os.path.exists(result_save_path):
    os.makedirs(result_save_path)

train_bce_loss = []
train_kld_loss = []
val_bce_loss = []
val_kld_loss = []
no_epochs_no_improvement = 0
best_val_loss = np.inf

for epoch in range(1, hyperparameters['num_epochs'] + 1):
    train_losses = train(epoch)
    train_bce_loss.append(train_losses[0])
    train_kld_loss.append(train_losses[1])

    val_losses = validate(epoch, result_save_path)
    val_bce_loss.append(val_losses[0])
    val_kld_loss.append(val_losses[1])
    val_loss = val_losses[0] + val_losses[1]

    with torch.no_grad():
        sample = torch.randn(64, hyperparameters['latent_dim']).to(hyperparameters['device'])
        sample = model.decode(sample).cpu()
        save_image(sample.view(64, 1, 28, 28), os.path.join(result_save_path, f"sample_{str(epoch)}.png"))
    
    # early stopping:
    if best_val_loss - val_loss > hyperparameters['early_stopping_min_delta']: # only when there is a real improvement
        no_epochs_no_improvement = 0
        best_val_loss = val_loss
    else:
        no_epochs_no_improvement += 1
        print(f"No improvement for {no_epochs_no_improvement} epochs.")
        if no_epochs_no_improvement >= hyperparameters['early_stopping_rounds']:
            print(f"No improvement for {no_epochs_no_improvement} epochs. Aborted training due to early stopping.")
            break
# Out:
# ====> Epoch: 1 Average train loss: 197.7685
# ====> Epoch: 1 Average validation loss: 190.3808
# ====> Epoch: 2 Average train loss: 189.6201
# ====> Epoch: 2 Average validation loss: 188.9663
# ====> Epoch: 3 Average train loss: 188.0826
# ====> Epoch: 3 Average validation loss: 187.6445
# ====> Epoch: 4 Average train loss: 187.0181
# ====> Epoch: 4 Average validation loss: 186.5131
# ====> Epoch: 5 Average train loss: 186.1376
# ====> Epoch: 5 Average validation loss: 186.1380
# ====> Epoch: 6 Average train loss: 185.5990
# ====> Epoch: 6 Average validation loss: 185.5435
# ====> Epoch: 7 Average train loss: 185.0637
# ====> Epoch: 7 Average validation loss: 184.8871
# ====> Epoch: 8 Average train loss: 184.5896
# ====> Epoch: 8 Average validation loss: 184.5009
# ====> Epoch: 9 Average train loss: 184.2312
# ====> Epoch: 9 Average validation loss: 184.6434
# ====> Epoch: 10 Average train loss: 183.8954
# ====> Epoch: 10 Average validation loss: 183.6061
# ====> Epoch: 11 Average train loss: 183.6158
# ====> Epoch: 11 Average validation loss: 183.9773
# ====> Epoch: 12 Average train loss: 183.3541
# ====> Epoch: 12 Average validation loss: 182.9564
# ====> Epoch: 13 Average train loss: 183.1071
# ====> Epoch: 13 Average validation loss: 182.8034
# ====> Epoch: 14 Average train loss: 182.9529
# ====> Epoch: 14 Average validation loss: 182.8438
# No improvement for 1 epochs.
# ====> Epoch: 15 Average train loss: 182.6983
# ====> Epoch: 15 Average validation loss: 182.4999
# ====> Epoch: 16 Average train loss: 182.5613
# ====> Epoch: 16 Average validation loss: 182.4494
# No improvement for 1 epochs.
# ====> Epoch: 17 Average train loss: 182.3923
# ====> Epoch: 17 Average validation loss: 182.5257
# ====> Epoch: 18 Average train loss: 182.3087
# ====> Epoch: 18 Average validation loss: 182.1138
# ====> Epoch: 19 Average train loss: 182.1156
# ====> Epoch: 19 Average validation loss: 182.4022
# ====> Epoch: 20 Average train loss: 182.0068
# ====> Epoch: 20 Average validation loss: 182.2659
# ====> Epoch: 21 Average train loss: 181.8226
# ====> Epoch: 21 Average validation loss: 181.9111
# ====> Epoch: 22 Average train loss: 181.7528
# ====> Epoch: 22 Average validation loss: 182.1442
# No improvement for 1 epochs.
# ====> Epoch: 23 Average train loss: 181.6082
# ====> Epoch: 23 Average validation loss: 181.7459
# No improvement for 2 epochs.
# ====> Epoch: 24 Average train loss: 181.5817
# ====> Epoch: 24 Average validation loss: 181.7555
# No improvement for 3 epochs.
# ====> Epoch: 25 Average train loss: 181.4327
# ====> Epoch: 25 Average validation loss: 181.5870
# ====> Epoch: 26 Average train loss: 181.3607
# ====> Epoch: 26 Average validation loss: 181.7408
# No improvement for 1 epochs.
# ====> Epoch: 27 Average train loss: 181.2602
# ====> Epoch: 27 Average validation loss: 181.4820
# No improvement for 2 epochs.
# ====> Epoch: 28 Average train loss: 181.1089
# ====> Epoch: 28 Average validation loss: 181.1296
# ====> Epoch: 29 Average train loss: 181.0398
# ====> Epoch: 29 Average validation loss: 181.2850
# No improvement for 1 epochs.
# ====> Epoch: 30 Average train loss: 180.9239
# ====> Epoch: 30 Average validation loss: 181.1652
# No improvement for 2 epochs.
# ====> Epoch: 31 Average train loss: 180.9634
# ====> Epoch: 31 Average validation loss: 181.1984
# No improvement for 3 epochs.
# ====> Epoch: 32 Average train loss: 180.7757
# ====> Epoch: 32 Average validation loss: 181.3970
# No improvement for 4 epochs.
# ====> Epoch: 33 Average train loss: 180.7178
# ====> Epoch: 33 Average validation loss: 181.1193
# ====> Epoch: 34 Average train loss: 180.5886
# ====> Epoch: 34 Average validation loss: 181.2812
# No improvement for 1 epochs.
# ====> Epoch: 35 Average train loss: 180.5183
# ====> Epoch: 35 Average validation loss: 180.9659
# No improvement for 2 epochs.
# ====> Epoch: 36 Average train loss: 180.4578
# ====> Epoch: 36 Average validation loss: 180.9263
# ====> Epoch: 37 Average train loss: 180.3714
# ====> Epoch: 37 Average validation loss: 180.4922
# ====> Epoch: 38 Average train loss: 180.2648
# ====> Epoch: 38 Average validation loss: 182.2321
# No improvement for 1 epochs.
# ====> Epoch: 39 Average train loss: 180.1535
# ====> Epoch: 39 Average validation loss: 180.6675
# ====> Epoch: 40 Average train loss: 180.1269
# ====> Epoch: 40 Average validation loss: 180.6136
# No improvement for 1 epochs.
# ====> Epoch: 41 Average train loss: 180.0619
# ====> Epoch: 41 Average validation loss: 181.7180
# No improvement for 2 epochs.
# ====> Epoch: 42 Average train loss: 179.9895
# ====> Epoch: 42 Average validation loss: 180.5319
# ====> Epoch: 43 Average train loss: 179.8898
# ====> Epoch: 43 Average validation loss: 180.2546
# ====> Epoch: 44 Average train loss: 179.8691
# ====> Epoch: 44 Average validation loss: 180.7871
# No improvement for 1 epochs.
# ====> Epoch: 45 Average train loss: 179.7484
# ====> Epoch: 45 Average validation loss: 180.4933
# No improvement for 2 epochs.
# ====> Epoch: 46 Average train loss: 179.6675
# ====> Epoch: 46 Average validation loss: 180.3747
# No improvement for 3 epochs.
# ====> Epoch: 47 Average train loss: 179.6115
# ====> Epoch: 47 Average validation loss: 180.9936
# No improvement for 4 epochs.
# ====> Epoch: 48 Average train loss: 179.6048
# ====> Epoch: 48 Average validation loss: 181.0029
# No improvement for 5 epochs.
# No improvement for 5 epochs. Aborted training due to early stopping.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
epochs = list(range(len(train_bce_loss)))

# 1: Train BCE
axs[0, 0].plot(epochs, train_bce_loss, label='Train BCE', color='blue')
axs[0, 0].set_title('Train BCE Loss')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].grid(True)

# 2: Train KLD
axs[0, 1].plot(epochs, train_kld_loss, label='Train KLD', color='orange')
axs[0, 1].set_title('Train KLD Loss')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].grid(True)

# 3: Val BCE
axs[1, 0].plot(epochs, val_bce_loss, label='Val BCE', color='green')
axs[1, 0].set_title('Val BCE Loss')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].grid(True)

# 4: Val KLD
axs[1, 1].plot(epochs, val_kld_loss, label='Val KLD', color='red')
axs[1, 1].set_title('Val KLD Loss')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualization

# %%
imgs = []
with torch.no_grad():
    z = torch.zeros(hyperparameters['latent_dim'])
    for z_param in range(hyperparameters['latent_dim']):
        row_imgs = []
        for val in torch.linspace(DISENTANGLEMENT_RANGE[0], DISENTANGLEMENT_RANGE[1], DISENTANGLEMENT_STEPS): # tensor with DISENTANGLEMENT_STEPS values ranging from DISENTANGLEMENT_RANGE[0] to DISENTANGLEMENT_RANGE[1]
            z_copy = z.clone()
            z_copy[z_param] = val  # nur eine Dimension ändern
            img = model.decode(z_copy.unsqueeze(0)) # add batch dimension
            row_imgs.append(img.view(28, 28).cpu().numpy()) # MNIST: 28x28
        imgs.append(row_imgs)
        

# Plot
fig, axes = plt.subplots(nrows=hyperparameters['latent_dim'], ncols=DISENTANGLEMENT_STEPS, figsize=(DISENTANGLEMENT_STEPS, hyperparameters['latent_dim']))

for dim in range(hyperparameters['latent_dim']):
    for step in range(DISENTANGLEMENT_STEPS):
        if hyperparameters['latent_dim'] != 1:
            ax = axes[dim, step]
            ax.imshow(imgs[dim][step], cmap='gray')
        else: 
            ax = axes[step]
            ax.imshow(imgs[dim][step], cmap='gray')
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Experimenting

# %%
torch.linspace(DISENTANGLEMENT_RANGE[0], DISENTANGLEMENT_RANGE[1], DISENTANGLEMENT_STEPS)
# Out:
# tensor([-2.0000, -1.4286, -0.8571, -0.2857,  0.2857,  0.8571,  1.4286,  2.0000])

# %%
z_test = torch.rand([-0.4, 2.0, -2.0, 2.0, -0.8, -2.0, -1.4, 2.0, 1.8, 0.8]).to(hyperparameters['device'])
img = model.decode(z_copy.unsqueeze(0))
img = img.view(28, 28).detach().cpu().numpy()
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 z_test = torch.rand([-0.4, 2.0, -2.0, 2.0, -0.8, -2.0, -1.4, 2.0, 1.8, 0.8]).to(hyperparameters['device'])
#       2 img = model.decode(z_copy.unsqueeze(0))
#       3 img = img.view(28, 28).detach().cpu().numpy()
#
# TypeError: rand(): argument 'size' (position 1) must be tuple of ints, but found element of type float at pos 0
